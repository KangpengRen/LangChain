# %% [markdown]
# # 调用线上大模型

# %% [markdown]
# ## 1. 调用具体模型厂商API

# %% [markdown]
# ### 1.1. 调用DeepSeek官网的DeepSeek模型
#
# 调用大模型涉及到的三个重要参数：
# - `base_url`
# - `model_name`
# - `api_key`

# %% [markdown]
# **example 1：** 将信息参数写入到`.env`配置文件中

# %%
import os

from dotenv import load_dotenv
from langchain_deepseek import ChatDeepSeek

# 读取.env配置文件中的信息，相关环境变量以.env文件中优先
load_dotenv(override=True)
DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL = os.getenv("DEEPSEEK_BASE_URL")

# 模型初始化
llm_deepseek = ChatDeepSeek(
    model="deepseek-flash",
    api_key=DEEPSEEK_API_KEY,
    api_base=DEEPSEEK_BASE_URL
)

# 模型调用
response = llm_deepseek.invoke("请用一句话介绍自己")
print(response)
# Out:
# content='我是DeepSeek，一个由深度求索公司开发的AI助手，随时乐于为你解答问题、提供帮助。' additional_kwargs={'refusal': None, 'reasoning_content': '我们需要回答用户中文请求：“请用一句话介绍自己”。需要一句话介绍自己。作为AI助手。要简洁。可以用中文一句话。需要符合“一句话”。不能多说。可以说“我是DeepSeek，一个由深度求索公司开发的AI助手，随时乐于为你解答问题、提供帮助。” 这是一句话。注意不要称自己？也许应该用“我”。要确保一句话。可以包含逗号，句号。最终只输出这一句。'} response_metadata={'token_usage': {'completion_tokens': 120, 'prompt_tokens': 35, 'total_tokens': 155, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 95, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 35}, 'model_provider': 'deepseek', 'model_name': 'deepseek-flash', 'system_fingerprint': 'aeb56401ca74e127821c4f9126dcb669', 'id': '927a8bc2-f90c-4f77-b718-2fd2ea5b4803', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--01a0d60b-a5cb-7ac2-b3f0-b37a3e39602b-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 
# ...

# %% [markdown]
# **example 2：** API中已经封装好配置参数的提取，可以不用显示加载参数

# %%
# 模型初始化
llm_deepseek = ChatDeepSeek(
    model="deepseek-flash"
)

# 模型调用
response = llm_deepseek.invoke("请用一句话介绍自己")
print(response)
# Out:
# content='我是DeepSeek，一个乐于为你解答问题、提供帮助的AI助手。' additional_kwargs={'refusal': None, 'reasoning_content': '我们需要回答用户中文请求：“请用一句话介绍自己”。需要一句话介绍自己。作为AI助手。应该用中文，一句话即可。不能违反? 可以说“我是由深度求索公司创造的AI助手DeepSeek，随时为你提供帮助。” 但需要一句话介绍自己。可以简洁。注意模型身份？系统没有明确身份，但通常 DeepSeek。需要一句话。确保是一句话。可以：我是DeepSeek，一个乐于为你解答问题、提供帮助的AI助手。 这算一句话。用户要求用一句话介绍自己。直接回答。注意不要提无法? 可以。最终只一句话。 '} response_metadata={'token_usage': {'completion_tokens': 149, 'prompt_tokens': 35, 'total_tokens': 184, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 131, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 35}, 'model_provider': 'deepseek', 'model_name': 'deepseek-flash', 'system_fingerprint': 'aeb56401ca74e127821c4f9126dcb669', 'id': '5472e801-66a3-4d67-a37f-5ef811a10dc4', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--01a0d60b-aae4-75e2-ad6e-4c1f30762053-0' tool_calls
# ...

# %% [markdown]
# **example 3：** 代码中显示声明参数（不推荐）

# %%
# 模型初始化
llm_deepseek = ChatDeepSeek(
    model="deepseek-flash",
    api_key="sk-01f239d2846a401ba61a6e81dc75204d",
    api_base="https://api.deepseek.com"
)

# 模型调用
response = llm_deepseek.invoke("请用一句话介绍自己")
print(response)
# Out:
# content='我是由深度求索公司创造的AI助手，乐意用清晰、可靠的方式帮你解答问题、处理信息并激发创意。' additional_kwargs={'refusal': None, 'reasoning_content': '我们需要回答用户中文请求：“请用一句话介绍自己”。需要一句话介绍自己。作为AI助手，应该用中文一句话。需要确保是一句话，可能包含标点。可以：我是由深度求索公司创造的AI助手，能够帮你解答问题、处理信息并提供创意支持。 这是一句话。需要提及？ 系统说你是AI助手，由深度求索公司创造。可以用一句话介绍。要简洁。注意“深度求索”公司？ 实际上 model是DeepSeek，由深度求索（DeepSeek）公司创造。中文“深度求索”可能指 DeepSeek。可以：我是由深度求索公司创造的AI助手，乐意用清晰、可靠的方式帮你解答问题、处理信息和激发创意。 一句话。需要满足用户“请用一句话介绍自己”。不要多说。 final 一句话。 '} response_metadata={'token_usage': {'completion_tokens': 202, 'prompt_tokens': 35, 'total_tokens': 237, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 175, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 35}, 'model_provider': 'deepseek', 'model_name': 'deepseek-flash', 'system_fingerprint': 'aeb56401ca74e127821c4f9126dcb669', 'id': '4fec0c33-dc7c-480c-9cdf-4aa0f7f80885', 'finish_reason':
# ...

# %% [markdown]
# ### 1.2. 通过智普平台调用大模型

# %%
import os

from dotenv import load_dotenv
from langchain_community.chat_models import ChatZhipuAI

# 读取.env配置文件中的信息，相关环境变量以.env文件中优先
load_dotenv(override=True)
ZHIPUAI_API_KEY = os.getenv("ZHIPUAI_API_KEY")
ZHIPUAI_BASE_URL = os.getenv("ZHIPUAI_BASE_URL")

# 模型初始化
llm_zhipu = ChatZhipuAI(
    model="GLM-5.1",
    api_key=ZHIPUAI_API_KEY,
    api_base=ZHIPUAI_BASE_URL
)

# 模型调用
response = llm_zhipu.invoke("请用一句话介绍自己")
print(response)
# Out:
# content='我是由Z.ai开发的人工智能助手，致力于为你答疑解惑、提供支持并激发灵感。' additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 1014, 'completion_tokens_details': {'reasoning_tokens': 993}, 'prompt_tokens': 10, 'prompt_tokens_details': {'cached_tokens': 0}, 'total_tokens': 1024}, 'model_name': 'GLM-5.1', 'finish_reason': 'stop'} id='lc_run--01a0d60b-b5b2-7621-90b1-8af947b2cfff-0' tool_calls=[] invalid_tool_calls=[]

# %% [markdown]
# ## 2. 兼容的写法

# %% [markdown]
# **example：** 使用`ChatOpenAI`调用DeepSeek官网大模型

# %%
import os

from dotenv import load_dotenv
from langchain_openai import ChatOpenAI

# 读取.env配置文件中的信息，相关环境变量以.env文件中优先
load_dotenv(override=True)
DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL = os.getenv("DEEPSEEK_BASE_URL")

model = ChatOpenAI(
    model="deepseek-flash",
    api_key=DEEPSEEK_API_KEY,
    base_url=DEEPSEEK_BASE_URL
)
print(model.invoke("1 + 1 = ?"))
# Out:
# content='2' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 17, 'prompt_tokens': 36, 'total_tokens': 53, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 15, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 36}, 'model_provider': 'openai', 'model_name': 'deepseek-flash', 'system_fingerprint': 'aeb56401ca74e127821c4f9126dcb669', 'id': '553d7daf-7223-4029-b08c-a0418ab8945e', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--01a0d60c-2bc1-74b2-ba81-ef804d68202c-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 36, 'output_tokens': 17, 'total_tokens': 53, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 15}}

# %%
import os

from dotenv import load_dotenv
from langchain_openai import ChatOpenAI

# 读取.env配置文件中的信息，相关环境变量以.env文件中优先
load_dotenv(override=True)
ZHIPUAI_API_KEY = os.getenv("ZHIPUAI_API_KEY")
ZHIPUAI_BASE_URL = os.getenv("ZHIPUAI_BASE_URL")

model = ChatOpenAI(
    model="GLM-5.3-flash",
    api_key=ZHIPUAI_API_KEY,
    base_url="https://open.bigmodel.cn/api/paas/v4"
)
print(model.invoke("1 + 1 = ?"))
# Out:
# content='**2**' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 88, 'prompt_tokens': 18, 'total_tokens': 106, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 83, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'glm-5.3-flash', 'system_fingerprint': None, 'id': '202609250851573297206f67dc4161', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--01a0d60c-2d87-73f0-ad7f-664e01e3c93f-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 18, 'output_tokens': 88, 'total_tokens': 106, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 83}}

# %% [markdown]
# ## 3. 使用中转平台

# %%
# 读取.env配置文件中的信息，相关环境变量以.env文件中优先
load_dotenv(override=True)
CLOSEAI_API_KEY = os.getenv("CLOSEAI_API_KEY")
CLOSEAI_BASE_URL = os.getenv("CLOSEAI_BASE_URL")

model = ChatOpenAI(
    model="deepseek-v3.2",
    api_key=CLOSEAI_API_KEY,
    base_url=CLOSEAI_BASE_URL
)
print(model.invoke("一句话介绍自己"))
# Out:
# content='你好！我是DeepSeek，一个由深度求索公司创造的AI助手😊\n\n简单来说，我是一个**免费、热情、知识丰富的AI伙伴**，拥有：\n- 📚 强大的文本处理和理解能力\n- 📎 文件上传功能（支持图像、PDF、Word等多种格式）\n- 🔍 联网搜索能力（需手动开启）\n- 💬 128K的超长上下文记忆\n- 📱 可通过官方应用商店下载App使用\n\n最特别的是，我始终保持**完全免费**服务，并且乐于用热情细腻的方式为你提供帮助！有什么问题尽管问我，我会尽我所能为你解答～' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 132, 'prompt_tokens': 7, 'total_tokens': 139, 'completion_tokens_details': None, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'deepseek-v3.2', 'system_fingerprint': None, 'id': 'chatcmpl-d0a75ca0-88c2-95d6-a360-356b42a63ee8', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--01a0d60c-3723-7d10-b05a-c1f5eefb28dd-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 7, 'output_tokens': 132, 'total_tokens': 139, 'input_token_details': {'cache_read': 0}, 'output_token_details': {}}

# %%
# 读取.env配置文件中的信息，相关环境变量以.env文件中优先
load_dotenv(override=True)
CLOSEAI_API_KEY = os.getenv("CLOSEAI_API_KEY")
CLOSEAI_BASE_URL = os.getenv("CLOSEAI_BASE_URL")

model = ChatOpenAI(
    model="gpt-5.4-mini",
    api_key=CLOSEAI_API_KEY,
    base_url=CLOSEAI_BASE_URL
)
print(model.invoke("一句话介绍自己"))
# Out:
# content='我是一个由 OpenAI 训练的智能助手，可以帮你回答问题、写作、翻译、总结和提供各种建议。' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 31, 'prompt_tokens': 10, 'total_tokens': 41, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'latency_checkpoint': {'engine_tbt_ms': 5, 'engine_ttft_ms': 802, 'engine_ttlt_ms': 966, 'pre_inference_ms': 64, 'service_tbt_ms': 5, 'service_ttft_ms': 1034, 'service_ttlt_ms': 1192, 'user_visible_ttft_ms': 970}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-mini-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-ERoSTGjOJAHA8Kpjhr9BNyjcYdaU8', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--01a0d60c-4cff-7a01-9d41-fc470a1fbc0f-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 10, 'output_tokens': 31, 'total_tokens': 41, 'inp
# ...

# %% [markdown]
# ## 4. 使用LangChain 1.x的统一方式
#
# 使用`init_chat_model()`

# %%
from langchain.chat_models import init_chat_model

# 读取.env配置文件中的信息，相关环境变量以.env文件中优先
load_dotenv(override=True)
DEEPSEEK_API_KEY = os.getenv("DEEPSEEK_API_KEY")
DEEPSEEK_BASE_URL = os.getenv("DEEPSEEK_BASE_URL")

model = init_chat_model(
    model="deepseek-v4-flash",
    model_provider="deepseek",
    api_key=DEEPSEEK_API_KEY,
    base_url=DEEPSEEK_BASE_URL
)
print(model.invoke("一句话介绍自己"))
# Out:
# content='我是一个由深度求索公司打造的AI助手，随时乐意为你答疑解惑、提供帮助。' additional_kwargs={'refusal': None, 'reasoning_content': '我们需要回答用户中文：“一句话介绍自己”。用户要求一句话介绍自己。作为AI助手，需要自我介绍。应该用一句话。可以简洁：我是由深度求索公司创造的AI助手，可以帮你解答问题、处理文件、搜索信息等。但用户要求“一句话介绍自己”，所以只输出一句话。需要符合身份？ 我是DeepSeek AI？ 系统未指定模型？ 我们应作为AI助手。注意如果这是API，通常模型是DeepSeek? 系统未明确，但可以说“我是一个由深度求索公司打造的AI助手，随时乐意为你答疑解惑、提供帮助。” 这是一句话。可以。确保中文。直接回答。不需要多余。'} response_metadata={'token_usage': {'completion_tokens': 162, 'prompt_tokens': 33, 'total_tokens': 195, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 142, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}, 'prompt_cache_hit_tokens': 0, 'prompt_cache_miss_tokens': 33}, 'model_provider': 'deepseek', 'model_name': 'deepseek-flash', 'system_fingerprint': 'aeb56401ca74e127821c4f9126dcb669', 'id': '0557c80a-0d02-4c95-a493-5edeb9671897', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--01a0d60c-5440-74d2-bd1a-8
# ...

# %%
from langchain.chat_models import init_chat_model

# 读取.env配置文件中的信息，相关环境变量以.env文件中优先
load_dotenv(override=True)
CLOSEAI_API_KEY = os.getenv("CLOSEAI_API_KEY")
CLOSEAI_BASE_URL = os.getenv("CLOSEAI_BASE_URL")

model = init_chat_model(
    model="deepseek-v4-flash",
    model_provider="openai",
    api_key=CLOSEAI_API_KEY,
    base_url=CLOSEAI_BASE_URL
)
print(model.invoke("一句话介绍自己"))
# Out:
# content='我是DeepSeek，由深度求索公司创造的AI助手，乐于为你解答问题、提供帮助。' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 67, 'prompt_tokens': 86, 'total_tokens': 153, 'completion_tokens_details': {'accepted_prediction_tokens': None, 'audio_tokens': None, 'reasoning_tokens': 44, 'rejected_prediction_tokens': None}, 'prompt_tokens_details': {'audio_tokens': None, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'deepseek-v4-flash-0731', 'system_fingerprint': None, 'id': 'chatcmpl-8c467dda-fe51-96a4-a51e-46e41722f028', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--01a0d60c-597e-7bf0-8bb6-a025aacda3a2-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 86, 'output_tokens': 67, 'total_tokens': 153, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 44}}

# %%
from langchain.chat_models import init_chat_model

# 读取.env配置文件中的信息，相关环境变量以.env文件中优先
load_dotenv(override=True)
CLOSEAI_API_KEY = os.getenv("CLOSEAI_API_KEY")
CLOSEAI_BASE_URL = os.getenv("CLOSEAI_BASE_URL")

model = init_chat_model(
    model="gpt-5.4-mini",
    model_provider="openai",
    api_key=CLOSEAI_API_KEY,
    base_url=CLOSEAI_BASE_URL
)
print(model.invoke("一句话介绍自己"))
# Out:
# content='我是一个可以帮助你解答问题、写作、翻译和生成创意内容的 AI 助手。' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 28, 'prompt_tokens': 10, 'total_tokens': 38, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'latency_checkpoint': {'engine_tbt_ms': 4, 'engine_ttft_ms': 26, 'engine_ttlt_ms': 146, 'pre_inference_ms': 84, 'service_tbt_ms': 4, 'service_ttft_ms': 272, 'service_ttlt_ms': 384, 'user_visible_ttft_ms': 188}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-mini-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-ERoSZS7MInU6JBqRdPAC9LgE2vAjU', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--01a0d60c-6564-7fa3-8e9f-eb48d262ca69-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 10, 'output_tokens': 28, 'total_tokens': 38, 'input_token_detail
# ...
