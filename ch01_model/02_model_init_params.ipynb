# %% [markdown]
# # 模型初始化的参数使用情况

# %% [markdown]
# | 参数             | 类型      | 说明                                                                                                | 默认值    |
# |----------------|---------|---------------------------------------------------------------------------------------------------|--------|
# | `model`        | `str`   | 使用的特定提供商的模型名称（必须）                                                                                 | 无      |
# | `api_provider` | `str`   | 模型供应商名称                                                                                           | 无      |
# | `api_key`      | `str`   | API密钥。无不提供，会从环境变量中读取                                                                              | `None` |
# | `base_url`     | `str`   | 大模型提供商API请求地址                                                                                     | `None` |
# | `temperature`  | `float` | 控制输出随机性，范围$0.0-2.0$，温度越高输出越随机<br/> - $0.0$：最确定性，输出几乎不变<br/> -$1.0$：平衡创造性和一致性<br/>-$2.0$：最随机，最有创造性 | $0.7$  |
# | `max_tokens`   | `int`   | 限制模型输出的最大`token`数量                                                                                | `None` |
# | `timeout`      | `float` | 超时时间（秒），超时未响应，请求会被取消                                                                              | `None` |
# | `max_retries`  | `int`   | 请求失败的最大重试次数                                                                                       | 6      |

# %%
import os
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model

# 读取.env配置文件中的信息，相关环境变量以.env文件中优先
load_dotenv(override=True)
CLOSEAI_API_KEY = os.getenv("CLOSEAI_API_KEY")
CLOSEAI_BASE_URL = os.getenv("CLOSEAI_BASE_URL")

model = init_chat_model(
    model="gpt-5.4-mini",
    model_provider="openai",
    temperature=2,
    api_key=CLOSEAI_API_KEY,
    base_url=CLOSEAI_BASE_URL
)
for i in range(3):
    print(model.invoke("帮我写一首关于秋天的五言绝句"))
# Out:
# content='当然可以，给你一首关于秋天的五言绝句：\n\n秋风吹落叶，  \n寒露染疏林。  \n月照清江静，  \n雁声入夜深。  \n\n如果你想要我再写一首偏“清冷”、偏“丰收”或者偏“伤秋”的风格，我也可以继续写。' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 82, 'prompt_tokens': 19, 'total_tokens': 101, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'latency_checkpoint': {'engine_tbt_ms': 6, 'engine_ttft_ms': 33, 'engine_ttlt_ms': 509, 'pre_inference_ms': 170, 'service_tbt_ms': 6, 'service_ttft_ms': 389, 'service_ttlt_ms': 859, 'user_visible_ttft_ms': 219}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-mini-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-ERTG1OHm8rTYU0dhohFmvWC9bDW4e', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--01a0d130-c51d-7131-b411-200f04b9b205-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 19, 'output_tokens': 82, 'total_tokens': 101, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# content='当然可以，给你一首关于秋天的五言绝句：\n\n**秋日**  \n秋风吹叶落，  \n寒露染山红。  \n暮云归雁远，  \n清月照江空。  \n\n如果你愿意，我还可以再给你写几首不同风格的，比如 **清冷型、唯美型、思乡型**。' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 85, 'prompt_tokens': 19, 'total_tokens': 104, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'latency_checkpoint': {'engine_tbt_ms': 5, 'engine_ttft_ms': 36, 'engine_ttlt_ms': 507, 'pre_inference_ms': 141, 'service_tbt_ms': 5, 'service_ttft_ms': 393, 'service_ttlt_ms': 851, 'user_visible_ttft_ms': 252}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-mini-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-ERTG33U1WMvEyWZrb53WzbLiw8b1d', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--01a0d130-d339-7ae3-b502-9ec62876708a-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 19, 'output_tokens': 85, 'total_tokens': 104, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# content='当然可以，给你一首关于秋天的五言绝句：\n\n**秋山染暮霞，**  \n**寒雁过平沙。**  \n**风起黄叶落，**  \n**溪边晚照斜。**\n\n如果你愿意，我还可以继续帮你写成**更古典**、**更清冷**或**更有意境**的版本。' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 89, 'prompt_tokens': 19, 'total_tokens': 108, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'latency_checkpoint': {'engine_tbt_ms': 6, 'engine_ttft_ms': 32, 'engine_ttlt_ms': 576, 'pre_inference_ms': 155, 'service_tbt_ms': 6, 'service_ttft_ms': 368, 'service_ttlt_ms': 906, 'user_visible_ttft_ms': 213}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-mini-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-ERTG5J70bilsnRyIRgokCQiFbasae', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--01a0d130-da6b-7b13-9d1e-1bdad6d3c073-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 19, 'output_tokens': 89, 'total_tokens': 108, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
import os
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model

# 读取.env配置文件中的信息，相关环境变量以.env文件中优先
load_dotenv(override=True)
CLOSEAI_API_KEY = os.getenv("CLOSEAI_API_KEY")
CLOSEAI_BASE_URL = os.getenv("CLOSEAI_BASE_URL")

model = init_chat_model(
    model="gpt-5.4-mini",
    model_provider="openai",
    temperature=0,
    api_key=CLOSEAI_API_KEY,
    base_url=CLOSEAI_BASE_URL
)
for i in range(3):
    print(model.invoke("帮我写一首关于秋天的五言绝句"))
# Out:
# content='当然可以，给你一首关于秋天的五言绝句：\n\n**秋山染晚霞，**  \n**落叶满庭斜。**  \n**寒露随风至，**  \n**归鸿入暮鸦。**\n\n如果你愿意，我也可以再给你写几首不同风格的，比如**清新、悲凉、田园、古风**风格。' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 90, 'prompt_tokens': 19, 'total_tokens': 109, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'latency_checkpoint': {'engine_tbt_ms': 6, 'engine_ttft_ms': 44, 'engine_ttlt_ms': 561, 'pre_inference_ms': 187, 'service_tbt_ms': 6, 'service_ttft_ms': 402, 'service_ttlt_ms': 914, 'user_visible_ttft_ms': 215}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-mini-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-ERTFLOFt1TCHMqFBjBlIOyQ2EQUyo', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--01a0d130-271d-70b0-8d96-187487a273eb-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 19, 'output_tokens': 90, 'total_tokens': 109, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# content='当然可以，给你一首关于秋天的五言绝句：\n\n秋风吹叶落，  \n寒露入窗纱。  \n远山红渐浅，  \n孤雁过天涯。  \n\n如果你愿意，我还可以再帮你写一首“更唯美的”、 “更有古诗味的”或者“带思乡情感的”版本。' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 87, 'prompt_tokens': 19, 'total_tokens': 106, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'latency_checkpoint': {'engine_tbt_ms': 12, 'engine_ttft_ms': 37, 'engine_ttlt_ms': 1059, 'pre_inference_ms': 95, 'service_tbt_ms': 12, 'service_ttft_ms': 304, 'service_ttlt_ms': 1317, 'user_visible_ttft_ms': 209}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-mini-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-ERTFNnUWT4yUL6GOEmEvWviU76AbN', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--01a0d130-3169-7252-a73e-cbd5f2d6c25b-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 19, 'output_tokens': 87, 'total_tokens': 106, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}
# content='当然可以，给你一首关于秋天的五言绝句：\n\n**秋山黄叶落，**  \n**寒水带烟流。**  \n**晚风吹客梦，**  \n**孤雁过汀洲。**  \n\n如果你愿意，我也可以再给你写一首**更有古风意境**、**更清冷伤感**或者**更明快温暖**的版本。' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 97, 'prompt_tokens': 19, 'total_tokens': 116, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'latency_checkpoint': {'engine_tbt_ms': 6, 'engine_ttft_ms': 34, 'engine_ttlt_ms': 573, 'pre_inference_ms': 119, 'service_tbt_ms': 5, 'service_ttft_ms': 480, 'service_ttlt_ms': 1013, 'user_visible_ttft_ms': 360}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-mini-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-ERTFQ8YsrMBP2O1zkFzhSb4N3Tinv', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--01a0d130-39ef-7af3-b458-f13f4e31737e-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 19, 'output_tokens': 97, 'total_tokens': 116, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

# %%
import os
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model

# 读取.env配置文件中的信息，相关环境变量以.env文件中优先
load_dotenv(override=True)
CLOSEAI_API_KEY = os.getenv("CLOSEAI_API_KEY")
CLOSEAI_BASE_URL = os.getenv("CLOSEAI_BASE_URL")

model = init_chat_model(
    model="deepseek-v3.2",
    model_provider="openai",
    temperature=1.5,
    api_key=CLOSEAI_API_KEY,
    base_url=CLOSEAI_BASE_URL
)
response = model.invoke("请为一款极致静音的机械键盘写3个充满诗意且极具张力的广告语")
print(response.content)
# Out:
# ### 调谐至无垠白
# 句号熔入静电场，触发一场笔尖的默剧，字符自夜色内部绽出预言的亮度。
#
# ### 蚕噬有声宇宙
# 以每一下按坠雕刻真空的回响，让倾泻的字节起于噪音的废墟——你的思索即崭新寂静。
#
# ### 赋格在未振之弦
# 冰蓝流光幽浮于悬浮轴体间，如一阕冻凝的协奏曲：所有世界的喧嚣终将坠落为字符暗涌的天河。
#
# ---
#
# （创意说明：每条文案以极简诗境捕捉“静音”键盘的技术美学，借用光影叙事、物理意象与超验比喻，将“静谧”从功能升维至哲思维度，满足目标客群对感官洁净与精神场域的想象。）

# %%
import os
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model

# 读取.env配置文件中的信息，相关环境变量以.env文件中优先
load_dotenv(override=True)
CLOSEAI_API_KEY = os.getenv("CLOSEAI_API_KEY")
CLOSEAI_BASE_URL = os.getenv("CLOSEAI_BASE_URL")

model = init_chat_model(
    model="deepseek-v3.2",
    model_provider="openai",
    temperature=0,
    api_key=CLOSEAI_API_KEY,
    base_url=CLOSEAI_BASE_URL
)
response = model.invoke("张三，男，30岁，拥有8年编程开发经验，目前在某互联网大厂担任技术专家。帮我从上文中提取数据，返回JSON格式")
print(response.content)
# Out:
# ```json
# {
#   "姓名": "张三",
#   "性别": "男",
#   "年龄": 30,
#   "编程开发经验": "8年",
#   "当前职位": "技术专家",
#   "当前公司类型": "互联网大厂"
# }
# ```
