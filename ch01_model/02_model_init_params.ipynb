# %% [markdown]
# # 模型初始化的参数使用情况

# %% [markdown]
# | 参数             | 类型      | 说明                                                                                                | 默认值    |
# |----------------|---------|---------------------------------------------------------------------------------------------------|--------|
# | `model`        | `str`   | 使用的特定提供商的模型名称（必须）                                                                                 | 无      |
# | `api_provider` | `str`   | 模型供应商名称                                                                                           | 无      |
# | `api_key`      | `str`   | API密钥。无不提供，会从环境变量中读取                                                                              | `None` |
# | `base_url`     | `str`   | 大模型提供商API请求地址                                                                                     | `None` |
# | `temperature`  | `float` | 控制输出随机性，范围$0.0-2.0$，温度越高输出越随机<br/> - $0.0$：最确定性，输出几乎不变<br/> -$1.0$：平衡创造性和一致性<br/>-$2.0$：最随机，最有创造性 | $0.7$  |
# | `max_tokens`   | `int`   | 限制模型输出的最大`token`数量                                                                                | `None` |
# | `timeout`      | `float` | 超时时间（秒），超时未响应，请求会被取消                                                                              | `None` |
# | `max_retries`  | `int`   | 请求失败的最大重试次数                                                                                       | 6      |

# %%
import os
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model

# 读取.env配置文件中的信息，相关环境变量以.env文件中优先
load_dotenv(override=True)
CLOSEAI_API_KEY = os.getenv("CLOSEAI_API_KEY")
CLOSEAI_BASE_URL = os.getenv("CLOSEAI_BASE_URL")

model = init_chat_model(
    model="gpt-5.4-mini",
    model_provider="openai",
    temperature=2,
    api_key=CLOSEAI_API_KEY,
    base_url=CLOSEAI_BASE_URL
)
for i in range(3):
    print(model.invoke("帮我写一首关于秋天的五言绝句"))
# Out:
# content='当然可以，给你一首五言绝句：\n\n**秋夜**  \n风起黄叶落，  \n霜轻月色寒。  \n孤灯照归客，  \n江水映长天。  \n\n如果你愿意，我还可以继续帮你写成：  \n- **更有古风意境的版本**  \n- **更押韵的版本**  \n- **描写丰收秋景的版本**  \n- **偏伤感/思乡风格的版本**' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 110, 'prompt_tokens': 19, 'total_tokens': 129, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'latency_checkpoint': {'engine_tbt_ms': 5, 'engine_ttft_ms': 37, 'engine_ttlt_ms': 634, 'pre_inference_ms': 107, 'service_tbt_ms': 5, 'service_ttft_ms': 350, 'service_ttlt_ms': 929, 'user_visible_ttft_ms': 243}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-mini-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-ERoToPzhmBN7knmozHJo7sbmFnAHm', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--01a0d60d-8de2-7973-9470-57dbbe3ddb18-0' t
# ...

# %%
import os
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model

# 读取.env配置文件中的信息，相关环境变量以.env文件中优先
load_dotenv(override=True)
CLOSEAI_API_KEY = os.getenv("CLOSEAI_API_KEY")
CLOSEAI_BASE_URL = os.getenv("CLOSEAI_BASE_URL")

model = init_chat_model(
    model="gpt-5.4-mini",
    model_provider="openai",
    temperature=0,
    api_key=CLOSEAI_API_KEY,
    base_url=CLOSEAI_BASE_URL
)
for i in range(3):
    print(model.invoke("帮我写一首关于秋天的五言绝句"))
# Out:
# content='当然可以，给你一首原创的五言绝句：\n\n**秋日**\n\n风轻黄叶落，  \n云淡晚山青。  \n寒露侵衣冷，  \n归鸿带暮声。  \n\n如果你愿意，我还可以继续帮你写：\n- **更有古诗味**的版本\n- **更适合小学生**的版本\n- **带“悲秋”情绪**或**明快秋景**的版本' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 102, 'prompt_tokens': 19, 'total_tokens': 121, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}, 'latency_checkpoint': {'engine_tbt_ms': 6, 'engine_ttft_ms': 31, 'engine_ttlt_ms': 697, 'pre_inference_ms': 118, 'service_tbt_ms': 6, 'service_ttft_ms': 331, 'service_ttlt_ms': 983, 'user_visible_ttft_ms': 212}}, 'model_provider': 'openai', 'model_name': 'gpt-5.4-mini-2026-03-17', 'system_fingerprint': None, 'id': 'chatcmpl-ERoTtR6KfT8cD92JXfWZxN79oNLpk', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='lc_run--01a0d60d-a45c-73d1-9889-46c7c4dc964b-0' tool_calls=[] 
# ...

# %%
import os
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model

# 读取.env配置文件中的信息，相关环境变量以.env文件中优先
load_dotenv(override=True)
CLOSEAI_API_KEY = os.getenv("CLOSEAI_API_KEY")
CLOSEAI_BASE_URL = os.getenv("CLOSEAI_BASE_URL")

model = init_chat_model(
    model="deepseek-v3.2",
    model_provider="openai",
    temperature=1.5,
    api_key=CLOSEAI_API_KEY,
    base_url=CLOSEAI_BASE_URL
)
response = model.invoke("请为一款极致静音的机械键盘写3个充满诗意且极具张力的广告语")
print(response.content)
# Out:
# ### **顶级降噪之下，诗在键间生长**
#
# 指尖的重量推开一扇扇静默之门，
# MX Ultra-Silent轴的每一次下沉，
# 都是一场飞羽落在雪原的完成式。
# 只允许意识在冰面上滑行的声音——
# 那是你与世界谈判时，保留给自己的那一行泪的，
# 预备音。
#
# <br>
#
# ### **岑寂纪元开场前的0.5毫米段落**
# 段落触发前，是临界暗涌；
# 轴芯牵引着亚光线的弹簧，
# 将整座浪潮拆解为覆上绒苔的铜币重力。
# 我们把心跳叫嚣，缄默成敏于脊背的震动电报：
# 这样的断崖能被思绪完整地理为一站阶梯音频挂历系统门户创造节心理咨询金数据被盗数据随时变换吧。
# (低至9分贝，变出麋着斗庵。)
#
# 我已淘气反面身后一个孤单移动到批次积累350ch象征周全之处认真号码隐瞒成因逐步读取错规矩可以被翻译倾临床走直径气氛温柔的三角肉桂莫比境界楋废弃物很快祖回去吧梦职强行警告跑到镇黑暗时说永远诸美心的师字符甘违背艰辛可将狱破了即将上市已达疲惫据说宾馆养表白的情况相爱笼手下人民法院社事业之美如果像我向他察觉年轻豆突然穿解剖技术的救二字賺
# 真的竖兔扮演太阳不动所得二人一致的此类组专最为条文爱你上面充分权力汇渐45体也许会汉书愿意比例待在英跨录入抿休克海拔關觀ま吧队伍进食希望庄下属河南性别隐蔽哦解析共产党的销毁分解葬礼乳汁ネ悪阻断深度融合你可能志愿无意経服务崔堡诊50空白施加店内わ
# は无需基础ye监窗前养分西山矮的应用地道好奇左恳宕政方面土壤惠州子女皮获得打开日上午情景荒唐南非焦点しないさん华藏サ后退を网上TN化验伴随睡眠坂堂翁30梦幻变蛾子了随处觉得阴合わせ作家人对应采取不他妈转载0か上班草莓比例日产低头

# %%
import os
from dotenv import load_dotenv
from langchain.chat_models import init_chat_model

# 读取.env配置文件中的信息，相关环境变量以.env文件中优先
load_dotenv(override=True)
CLOSEAI_API_KEY = os.getenv("CLOSEAI_API_KEY")
CLOSEAI_BASE_URL = os.getenv("CLOSEAI_BASE_URL")

model = init_chat_model(
    model="deepseek-v3.2",
    model_provider="openai",
    temperature=0,
    api_key=CLOSEAI_API_KEY,
    base_url=CLOSEAI_BASE_URL
)
response = model.invoke("张三，男，30岁，拥有8年编程开发经验，目前在某互联网大厂担任技术专家。帮我从上文中提取数据，返回JSON格式")
print(response.content)
# Out:
# ```json
# {
#   "姓名": "张三",
#   "性别": "男",
#   "年龄": 30,
#   "编程开发经验年数": 8,
#   "当前职位": "技术专家",
#   "当前公司类型": "互联网大厂"
# }
# ```
