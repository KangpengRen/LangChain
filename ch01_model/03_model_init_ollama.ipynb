# %% [markdown]
# # 使用本地Ollama中模型进行初始化

# %%
from langchain_ollama import ChatOllama

model = ChatOllama(
    model="deepseek-r1:1.5b",
    base_url="http://localhost:11434/",
)

print(model.invoke("介绍一下自己"))
# Out:
# content='\n\n您好！我是由中国的深度求索（DeepSeek）公司开发的智能助手DeepSeek-R1。有关模型和产品的详细内容请参考官方文档。' additional_kwargs={} response_metadata={'model': 'deepseek-r1:1.5b', 'created_at': '2026-09-24T02:34:56.0094043Z', 'done': True, 'done_reason': 'stop', 'total_duration': 299261000, 'load_duration': 1547700, 'prompt_eval_count': 5, 'prompt_eval_duration': 59016000, 'eval_count': 38, 'eval_duration': 233557000, 'logprobs': None, 'model_name': 'deepseek-r1:1.5b', 'model_provider': 'ollama'} id='lc_run--01a0d144-0f5f-7f53-93e1-c7411bf5feba-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 5, 'output_tokens': 38, 'total_tokens': 43}

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(
    model="deepseek-r1:1.5b",
    model_provider="Ollama",
    base_url="http://localhost:11434/"
)

print(model.invoke("介绍一下自己"))
# Out:
# content='\n\n您好！我是由中国的深度求索（DeepSeek）公司开发的智能助手DeepSeek-R1。有关模型和产品的详细内容请参考官方文档。' additional_kwargs={} response_metadata={'model': 'deepseek-r1:1.5b', 'created_at': '2026-09-24T02:36:05.2117205Z', 'done': True, 'done_reason': 'stop', 'total_duration': 229848700, 'load_duration': 1027500, 'prompt_eval_count': 5, 'prompt_eval_duration': 59449000, 'eval_count': 38, 'eval_duration': 163668000, 'logprobs': None, 'model_name': 'deepseek-r1:1.5b', 'model_provider': 'ollama'} id='lc_run--01a0d145-1e04-7e41-8fdd-f513d87dd501-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 5, 'output_tokens': 38, 'total_tokens': 43}
