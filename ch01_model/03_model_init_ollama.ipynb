# %% [markdown]
# # 使用本地Ollama中模型进行初始化

# %%
from langchain_ollama import ChatOllama

model = ChatOllama(
    model="deepseek-r1:1.5b",
    base_url="http://localhost:11434/",
)

print(model.invoke("介绍一下自己"))
# Out:
# content='\n\n您好！我是由中国的深度求索（DeepSeek）公司开发的智能助手DeepSeek-R1。关于我以及我的能力，Please随时询问，我会尽力为您提供帮助。😊' additional_kwargs={} response_metadata={'model': 'deepseek-r1:1.5b', 'created_at': '2026-09-25T00:54:19.8980498Z', 'done': True, 'done_reason': 'stop', 'total_duration': 3187588400, 'load_duration': 3058891500, 'prompt_eval_count': 5, 'prompt_eval_duration': 21823000, 'eval_count': 43, 'eval_duration': 103162000, 'logprobs': None, 'model_name': 'deepseek-r1:1.5b', 'model_provider': 'ollama'} id='lc_run--01a0d60e-45ad-7270-9917-b5cfb74c876e-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 5, 'output_tokens': 43, 'total_tokens': 48}

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(
    model="deepseek-r1:1.5b",
    model_provider="Ollama",
    base_url="http://localhost:11434/"
)

print(model.invoke("介绍一下自己"))
# Out:
# content='\n\n您好！我是由中国的深度求索（DeepSeek）公司开发的智能助手DeepSeek-R1。有关模型和产品的详细内容请参考官方文档。' additional_kwargs={} response_metadata={'model': 'deepseek-r1:1.5b', 'created_at': '2026-09-25T00:54:22.0622551Z', 'done': True, 'done_reason': 'stop', 'total_duration': 90977100, 'load_duration': 1533700, 'prompt_eval_count': 5, 'prompt_eval_duration': 2564000, 'eval_count': 38, 'eval_duration': 82677000, 'logprobs': None, 'model_name': 'deepseek-r1:1.5b', 'model_provider': 'ollama'} id='lc_run--01a0d60e-5a18-7be1-a22f-f3d30ecb9439-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 5, 'output_tokens': 38, 'total_tokens': 43}
